# %% [markdown]
# <a href="https://colab.research.google.com/github/ajohn256/blackboard-app/blob/main/stegnography_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update && !sudo apt-get upgrade
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1,014 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,360 kB]
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,299 kB]
# ...

# %%
# !pip install buildozer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 58.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 35.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.3.0
#     Uninstalling platformdirs-3.3.0:
#       Successfully uninstalled platformdirs-3.3.0
# ...

# %%
# !pip install cython==0.29.21
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.2/974.2 kB 20.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cython
#     Found existing installation: Cython 0.29.19
#     Uninstalling Cython-0.29.19:
#       Successfully uninstalled Cython-0.29.19
# ...

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# python3-dev is already the newest version (3.8.2-0ubuntu2).
# python3-dev set to manually installed.
# build-essential is already the newest version (12.8ubuntu1.1).
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# libavcodec-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libswscale-dev set to manually installed.
# The following additional packages will be installed:
# ...

# %%
# !sudo apt-get install -y \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libgstreamer1.0-dev' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0-dbg' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0' for regex 'libgstreamer1.0'
# libgstreamer1.0-0 is already the newest version (1.16.3-0ubuntu1.1).
# libgstreamer1.0-0 set to manually installed.
# The following additional packages will be installed:
#   autopoint debhelper dh-autoreconf dh-strip-nondeterminism dwz gettext
#   gettext-base gir1.2-gstreamer-1.0 gstreamer1.0-x intltool-debian libaa1
#   libarchive-cpio-perl libarchive-zip-perl libcdparanoia0 libcroco3
#   libdebhelper-perl libdv4 libfile-stripnondeterminism-perl
#   libgstreamer-plugins-good1.0-0 libmail-sendmail-perl libshout3
#   libsub-override-perl libsys-hostname-long-perl libtag1v5 libtag1v5-vanilla
#   libtool libv4l-0 libv4lconvert0 libvisual-0.4-0 po-debconf
# Suggested packages:
# ...

# %%
# !sudo apt-get install libffi7
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libffi7 is already the newest version (3.3-4).
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.

# %%
# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi7
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# bzip2 is already the newest version (1.0.8-2).
# libbz2-dev is already the newest version (1.0.8-2).
# libbz2-dev set to manually installed.
# libffi-dev is already the newest version (3.3-4).
# libffi-dev set to manually installed.
# libffi7 is already the newest version (3.3-4).
# libreadline-dev is already the newest version (8.0-4).
# libreadline-dev set to manually installed.
# build-essential is already the newest version (12.8ubuntu1.1).
# liblzma-dev is already the newest version (5.2.4-1ubuntu1.1).
# liblzma-dev set to manually installed.
# libsqlite3-dev is already the newest version (3.31.1-4ubuntu0.5).
# libsqlite3-dev set to manually installed.
# libssl-dev is already the newest version (1.1.1f-1ubuntu2.19).
# openssl is already the newest version (1.1.1f-1ubuntu2.19).
# openssl set to manually installed.
# uuid-dev is already the newest version (2.34-0.1ubuntu9.4).
# ...

# %%
# !sudo apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libffi-dev is already the newest version (3.3-4).
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.

# %%
# !buildozer -v android debug
# Out:
# Streaming output truncated to the last 5000 lines.
# Listing '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/arm64-v8a/Cython/Compiler/Tests'...
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/arm64-v8a/Cython/Compiler/Tests/TestBuffer.py'...
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/arm64-v8a/Cython/Compiler/Tests/TestCmdLine.py'...
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/arm64-v8a/Cython/Compiler/Tests/TestFlowControl.py'...
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/arm64-v8a/Cython/Compiler/Tests/TestGrammar.py'...
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/arm64-v8a/Cython/Compiler/Tests/TestMemView.py'...
# ...

# %%
# !buildozer android clean
# Out:
# # Check configuration tokens
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# # Ensure build layout
# # Check configuration tokens
# # Run ['/usr/bin/python3', '-m', 'pythonforandroid.toolchain', 'clean_builds', '--color=always', '--storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_x86_64', '--ndk-api=21', '--ignore-setup-py', '--debug']
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# /content/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py:59: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(cur_ver) < LooseVersion(version):
# ...

# %%
# !buildozer -v android debug
# Out:
# Streaming output truncated to the last 5000 lines.
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/x86_64/kivymd/uix/behaviors/toggle_behavior.py'...
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/x86_64/kivymd/uix/behaviors/touch_behavior.py'...
# Listing '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/x86_64/kivymd/uix/bottomnavigation'...
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/x86_64/kivymd/uix/bottomnavigation/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/x86_64/kivymd/uix/bottomnavigation/bottomnavigation.py'...
# Listing '/content/.buildozer/android/platform/build-arm64-v8a_x86_64/build/python-installs/stegnography/x86_64/kivymd/uix/bottomsheet'...
# ...
